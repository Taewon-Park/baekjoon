# %% [markdown]
# # #01. [2557] Hello World
# ---
#
# ## 문제
#  Hello World!를 출력하시오.
#
# ---
#
# ## 입력
# 없음
#
# ---
#
# ## 출력
# Hello World!를 출력하시오.
#
# ---
#
# 링크 : https://www.acmicpc.net/problem/2557

# %%
print("Hello World!")
# Out:
# Hello World!
