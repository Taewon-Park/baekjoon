# %% [markdown]
# # #12. [10171] 고양이
# ---
#
# ## 문제
# 아래 예제와 같이 고양이를 출력하시오.
#
# ---
#
# ## 입력
# 없음.
#
# ---
#
# ## 출력
# 고양이를 출력한다.
#
# ---
# 링크 : https://www.acmicpc.net/problem/10171

# %%
print('\    /\ \n )  ( '"'"') \n(  /  ) \n \(__)|')
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|
